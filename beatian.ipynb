# %% [markdown]
# Evet Bakalım Beauty Analysis Çalışalım biraz.

# %%
import cv2
import matplotlib.pyplot as plt
import skimage.io as imageio
import numpy as np
import pandas as pd

# %%
mar=cv2.imread("/Users/anilkaynar/Desktop/marion12.jpg")

# %%
imageio.imshow(mar)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
rgb=cv2.cvtColor(mar,cv2.COLOR_BGR2RGB)
imageio.imshow(rgb)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
import dlib
#detector = dlib.get_frontal_face_detector()
eyedetect=cv2.CascadeClassifier('/Users/anilkaynar/Documents/haarcascade_eye.xml.txt')

# %%
geteye=eyedetect.detectMultiScale(rgb)

# %%
geteye
# Out:
# array([[551, 330,  22,  22],
#        [601, 438, 159, 159],
#        [352, 468, 137, 137],
#        [459, 806, 262, 262]], dtype=int32)

# %%
gozler=[]
for (x,y,w,h) in geteye:
    gozler.append(rgb[y:y+h, x:x+w])
imageio.imshow(gozler[0])
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imageio.imshow(gozler[1])
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imageio.imshow(gozler[2])
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imageio.imshow(gozler[3])
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# İnteresting. Her eye is almost gray.

# %% [markdown]
# O değil sivilcesini göz saymak da iyiymiş yahu.

# %%
selena=cv2.imread("/Users/anilkaynar/Desktop/selenaold.jpg")
selenargb=cv2.cvtColor(selena,cv2.COLOR_BGR2RGB)
imageio.imshow(selenargb)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# İt's big image. Also his face is tuned.

# %%
seleyes=eyedetect.detectMultiScale(selenargb)
len(seleyes)
# Out:
# 16

# %%
seleyes
# Out:
# array([[361,  76,  37,  37],
#        [426,  76,  36,  36],
#        [390, 128,  20,  20],
#        [215, 272,  24,  24],
#        [234, 275,  23,  23],
#        [557, 269,  29,  29],
#        [270, 280,  28,  28],
#        [448, 313,  23,  23],
#        [495, 274,  28,  28],
#        [247, 314,  24,  24],
#        [412, 343,  24,  24],
#        [191, 358,  25,  25],
#        [529, 375,  24,  24],
#        [199, 285,  48,  48],
#        [399, 403,  22,  22],
#        [417, 328,  49,  49]], dtype=int32)

# %%
gomgoz=[]
for (x,y,w,h) in seleyes:
    gomgoz.append(selenargb[y:y+h, x:x+w])
imageio.imshow(gomgoz[0])
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
import matplotlib.pyplot as plt
for gz in gomgoz:
    plt.imshow(gz)
    plt.show()

# %% [markdown]
# Kulak mulak hepsini almış yahu. Acaba bir yüzde falan var mı?

# %% [markdown]
# Yok direkt olarak arrayi döndürüyor.

# %% [markdown]
# Evet gözleri dlibten çekmemiz çok daha mantıklı olacaktır.

# %%
from imutils import face_utils
detector = dlib.get_frontal_face_detector()
detect=detector(selenargb,1)
predictor = dlib.shape_predictor("/Users/anilkaynar/Downloads/shape_predictor_68_face_landmarks.dat")
shape=predictor(selenargb,detect[0])
print(shape)

# %%
shape.part(0) #Evet közleri bu şekilde kesmeye çalışalım.
# Out:
# point(338, 95)

# %%
shape.part(36)
# Out:
# point(366, 95)

# %%
shape.part(39)
# Out:
# point(393, 97)

# %%
x1=shape.part(36).x
x2=shape.part(39).x
#43 46
y1=shape.part(42).y
y2=shape.part(45).y
print("{1} : {2} {3} : {4}",x1,x2,y1,y2)
# Out:
# {1} : {2} {3} : {4} 366 393 98 96

# %% [markdown]
# Doktor bu niye kıl gibi oldu yahu.

# %%
gozdlib=selenargb[x1:x2,y2:y1]
imageio.imshow(gozdlib)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
gozdlib=selenargb[y2:y1,x1:x2]
imageio.imshow(gozdlib)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# Yav doktor niye böyle oldu yahu.

# %%
gozdlib=selenargb[y2:y1+5,x1:x2]
imageio.imshow(gozdlib)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
gozdlib=selenargb[y2-7:y1+3,x1:x2]
imageio.imshow(gozdlib)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# Yani gözü alabiliyoruz bu şekilde.

# %%
imageio.imshow(rgb)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
detect=detector(rgb,1)
predictor = dlib.shape_predictor("/Users/anilkaynar/Downloads/shape_predictor_68_face_landmarks.dat")
shape=predictor(rgb,detect[0])

# %%
x1=shape.part(36).x
x2=shape.part(39).x
#43 46
y1=shape.part(42).y
y2=shape.part(45).y
print("{1} : {2} {3} : {4}",x1,x2,y1,y2)
# Out:
# {1} : {2} {3} : {4} 383 487 537 517

# %%
frans=rgb[y2:y1,x1:x2]
imageio.imshow(frans)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# Yani alabiliyoruz yahu. Tamamını almak için biraz daha uğraşmak lazım herhalde.

# %%
frans=rgb[y2:y1+13,x1:x2]
imageio.imshow(frans)
#39 42
#37 40
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
x1=shape.part(36).x
x2=shape.part(39).x
#43 46
y1=shape.part(37).y
y2=shape.part(40).y

# %%
frans=rgb[y1:y2,x1:x2]
imageio.imshow(frans)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
print(y1,y2)
# Out:
# 520 555

# %% [markdown]
# İt's looks just fine. We easily detect eyes.

# %% [markdown]
# Dlib ile gözü çekmek çok daha mantıklı.

# %%
x1=shape.part(42).x
x2=shape.part(45).x
#43 46
#44 47
y1=shape.part(43).y
y2=shape.part(46).y
print(x1,x2,y1,y2)
# Out:
# 635 737 506 534

# %%
franssag=rgb[y1:y2,x1:x2]
imageio.imshow(franssag)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# İt's works my friends it's works!!!!!!!!!!

# %%
x1=shape.part(42).x
x2=shape.part(45).x
#43 46
#44 47
y1=shape.part(44).y
y2=shape.part(47).y
print(x1,x2,y1,y2)
franssag2=rgb[y1:y2,x1:x2]
imageio.imshow(franssag2)
# Out:
# 635 737 500 538
# /anaconda3/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %% [markdown]
# yani bu kadar yapacak başka bir şey yok.
